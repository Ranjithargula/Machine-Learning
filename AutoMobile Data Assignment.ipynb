# %% [markdown]
# # Automobile data

# %%
import numpy as np
import pandas as pd

# %%
df=pd.read_csv('https://pynative.com/wp-content/uploads/2019/01/Automobile_data.csv')
df

# %%
F5=df.head()

# %%
L5=df.tail()

# %%
F5
# Out:
#    index      company   body-style  wheel-base  length engine-type  \
# 0      0  alfa-romero  convertible        88.6   168.8        dohc
# 1      1  alfa-romero  convertible        88.6   168.8        dohc
# 2      2  alfa-romero    hatchback        94.5   171.2        ohcv
# 3      3         audi        sedan        99.8   176.6         ohc
# 4      4         audi        sedan        99.4   176.6         ohc
#
#   num-of-cylinders  horsepower  average-mileage    price
# 0             four         111               21  13495.0
# 1             four         111               21  16500.0
# 2              six         154               19  16500.0
# 3             four         102               24  13950.0
# 4             five         115               18  17450.0

# %%
L5
# Out:
#     index     company body-style  wheel-base  length engine-type  \
# 56     81  volkswagen      sedan        97.3   171.7         ohc
# 57     82  volkswagen      sedan        97.3   171.7         ohc
# 58     86  volkswagen      sedan        97.3   171.7         ohc
# 59     87       volvo      sedan       104.3   188.8         ohc
# 60     88       volvo      wagon       104.3   188.8         ohc
#
#    num-of-cylinders  horsepower  average-mileage    price
# 56             four          85               27   7975.0
# 57             four          52               37   7995.0
# 58             four         100               26   9995.0
# 59             four         114               23  12940.0
# 60             four         114               23  13415.0

# %%
del df['index']
df.sort_values(by='horsepower')
df['index']=[i for i in range(61)]
df

# %%
df.set_index('index')
# Out:
#              company   body-style  wheel-base  length engine-type  \
# index
# 0        alfa-romero  convertible        88.6   168.8        dohc
# 1        alfa-romero  convertible        88.6   168.8        dohc
# 2        alfa-romero    hatchback        94.5   171.2        ohcv
# 3               audi        sedan        99.8   176.6         ohc
# 4               audi        sedan        99.4   176.6         ohc
# 5               audi        sedan        99.8   177.3         ohc
# 6               audi        wagon       105.8   192.7         ohc
# 7                bmw        sedan       101.2   176.8         ohc
# 8                bmw        sedan       101.2   176.8         ohc
# 9                bmw        sedan       101.2   176.8         ohc
# 10               bmw        sedan       103.5   189.0         ohc
# 11               bmw        sedan       103.5   193.8         ohc
# 12               bmw        sedan       110.0   197.0         ohc
# ...

# %%
df.isnull().sum()
# Out:
# company             0
# body-style          0
# wheel-base          0
# length              0
# engine-type         0
# num-of-cylinders    0
# horsepower          0
# average-mileage     0
# price               3
# index               0
# dtype: int64

# %%
df=df.sort_values(by='horsepower')

df['price']=df['price'].fillna(df['price'].interpolate())

df.isnull().sum()
# Out:
# company             0
# body-style          0
# wheel-base          0
# length              0
# engine-type         0
# num-of-cylinders    0
# horsepower          0
# average-mileage     0
# price               0
# index               0
# dtype: int64

# %%
f=df.set_index('index')
f.to_csv("A2.csv")
f
# Out:
#              company   body-style  wheel-base  length engine-type  \
# index
# 13         chevrolet    hatchback        88.4   141.1           l
# 55        volkswagen        sedan        97.3   171.7         ohc
# 57        volkswagen        sedan        97.3   171.7         ohc
# 40            nissan        sedan        94.5   165.3         ohc
# 52            toyota        wagon        95.7   169.7         ohc
# 50            toyota    hatchback        95.7   158.7         ohc
# 53            toyota        wagon        95.7   169.7         ohc
# 49            toyota    hatchback        95.7   158.7         ohc
# 48            toyota    hatchback        95.7   158.7         ohc
# 51            toyota        wagon        95.7   169.7         ohc
# 17             dodge    hatchback        93.7   157.3         ohc
# 27             mazda    hatchback        93.1   159.1         ohc
# 36        mitsubishi    hatchback        93.7   157.3         ohc
# ...

# %%
df=df.sort_values(by='price')

L=df.tail(1)
L
# Out:
#           company body-style  wheel-base  length engine-type num-of-cylinders  \
# 35  mercedes-benz    hardtop       112.0   199.2        ohcv            eight
#
#     horsepower  average-mileage    price  index
# 35         184               14  45400.0     35

# %%
max_company=L['company']

print(max_company)
# Out:
# 35    mercedes-benz
# Name: company, dtype: object

# %%
print(max_company.to_string(index=False))
# Out:
#  mercedes-benz

# %%
l=[]
for i in range(len(df['company'])):
    if df['company'][i]=='toyota':
        l.append(df['index'][i])
        
l
# Out:
# [48, 49, 50, 51, 52, 53, 54]

# %%
f=f.sort_values(by='index')

f
# Out:
#              company   body-style  wheel-base  length engine-type  \
# index
# 0        alfa-romero  convertible        88.6   168.8        dohc
# 1        alfa-romero  convertible        88.6   168.8        dohc
# 2        alfa-romero    hatchback        94.5   171.2        ohcv
# 3               audi        sedan        99.8   176.6         ohc
# 4               audi        sedan        99.4   176.6         ohc
# 5               audi        sedan        99.8   177.3         ohc
# 6               audi        wagon       105.8   192.7         ohc
# 7                bmw        sedan       101.2   176.8         ohc
# 8                bmw        sedan       101.2   176.8         ohc
# 9                bmw        sedan       101.2   176.8         ohc
# 10               bmw        sedan       103.5   189.0         ohc
# 11               bmw        sedan       103.5   193.8         ohc
# 12               bmw        sedan       110.0   197.0         ohc
# ...

# %%
f.iloc[l[0]:(l[-1]+1),:]
# Out:
#       company body-style  wheel-base  length engine-type num-of-cylinders  \
# index
# 48     toyota  hatchback        95.7   158.7         ohc             four
# 49     toyota  hatchback        95.7   158.7         ohc             four
# 50     toyota  hatchback        95.7   158.7         ohc             four
# 51     toyota      wagon        95.7   169.7         ohc             four
# 52     toyota      wagon        95.7   169.7         ohc             four
# 53     toyota      wagon        95.7   169.7         ohc             four
# 54     toyota      wagon       104.5   187.8        dohc              six
#
#        horsepower  average-mileage    price
# index
# 48             62               35   5348.0
# 49             62               31   6338.0
# 50             62               31   6488.0
# 51             62               31   6918.0
# 52             62               27   7898.0
# 53             62               27   8778.0
# 54            156               19  15750.0

# %%
from collections import Counter
count=Counter(df['company'])
dic=dict(count)

dic
# Out:
# {'chevrolet': 3,
#  'mazda': 5,
#  'toyota': 7,
#  'mitsubishi': 4,
#  'dodge': 2,
#  'isuzu': 3,
#  'nissan': 5,
#  'honda': 3,
#  'volkswagen': 4,
#  'volvo': 2,
#  'alfa-romero': 3,
#  'audi': 4,
#  'bmw': 6,
#  'mercedes-benz': 4,
#  'jaguar': 3,
#  'porsche': 3}

# %%
ex_car={}
for i in dic:
    max_price=0
    for j in range(len(df['company'])):
        if i==df['company'][j]:
            if max_price<df['price'][j]:
                max_price=df['price'][j]
    ex_car[i]=max_price
ex_car
# Out:
# {'chevrolet': 6575.0,
#  'mazda': 18344.0,
#  'toyota': 15750.0,
#  'mitsubishi': 8189.0,
#  'dodge': 6377.0,
#  'isuzu': 12319.5,
#  'nissan': 13499.0,
#  'honda': 12945.0,
#  'volkswagen': 9995.0,
#  'volvo': 13415.0,
#  'alfa-romero': 16500.0,
#  'audi': 18920.0,
#  'bmw': 41315.0,
#  'mercedes-benz': 45400.0,
#  'jaguar': 36000.0,
#  'porsche': 37028.0}

# %%
l=list(ex_car.values())
i_list=[]
for i in range(len(df['price'])):
    for j in l:
        if df['price'][i]==j:
            i_list.append(i)

print(i_list)
x=[]

for i in range(len(i_list)):
    x.append(f.iloc[i_list[i],:])

f=pd.DataFrame(x)

f
# Out:
# [1, 2, 6, 11, 15, 16, 19, 23, 26, 31, 35, 39, 44, 46, 47, 54, 58, 60]
#           company   body-style  wheel-base  length engine-type  \
# 1     alfa-romero  convertible        88.6   168.8        dohc
# 2     alfa-romero    hatchback        94.5   171.2        ohcv
# 6            audi        wagon       105.8   192.7         ohc
# 11            bmw        sedan       103.5   193.8         ohc
# 15      chevrolet        sedan        94.5   158.8         ohc
# 16          dodge    hatchback        93.7   157.3         ohc
# 19          honda        sedan        96.5   175.4         ohc
# 23          isuzu        sedan        94.5   155.9         ohc
# 26         jaguar        sedan       102.0   191.7        ohcv
# 31          mazda        sedan       104.9   175.0         ohc
# 35  mercedes-benz      hardtop       112.0   199.2        ohcv
# 39     mitsubishi        sedan        96.3   172.4         ohc
# 44         nissan        sedan       100.4   184.6        ohcv
# ...

# %%
df=df.sort_values('index')

# %%
dic
# Out:
# {'chevrolet': 3,
#  'mazda': 5,
#  'toyota': 7,
#  'mitsubishi': 4,
#  'dodge': 2,
#  'isuzu': 3,
#  'nissan': 5,
#  'honda': 3,
#  'volkswagen': 4,
#  'volvo': 2,
#  'alfa-romero': 3,
#  'audi': 4,
#  'bmw': 6,
#  'mercedes-benz': 4,
#  'jaguar': 3,
#  'porsche': 3}

# %%
avg_list={}
for i in dic:
    sum_milg=0
    for j in range(len(df['company'])):
        if i==df['company'][j]:
            sum_milg+=df['average-mileage'][j]
    avg_milg=sum_milg/dic[i]
    avg_list[i]=avg_milg

avg_list
# Out:
# {'chevrolet': 41.0,
#  'mazda': 28.0,
#  'toyota': 28.714285714285715,
#  'mitsubishi': 29.5,
#  'dodge': 31.0,
#  'isuzu': 33.333333333333336,
#  'nissan': 31.4,
#  'honda': 26.333333333333332,
#  'volkswagen': 31.75,
#  'volvo': 23.0,
#  'alfa-romero': 20.333333333333332,
#  'audi': 20.0,
#  'bmw': 19.0,
#  'mercedes-benz': 18.0,
#  'jaguar': 14.333333333333334,
#  'porsche': 17.0}
